# %%
import pandas as pd

# %%
pd.__file__
# Out:
# '/workspaces/data-engineering-2026/pipeline/.venv/lib/python3.13/site-packages/pandas/__init__.py'

# %%
# Read a sample of the data
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/'
df = pd.read_csv(prefix + 'yellow_tripdata_2021-01.csv.gz')
# Out:
# /tmp/ipykernel_26904/1139265719.py:3: DtypeWarning: Columns (0: store_and_fwd_flag) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(prefix + 'yellow_tripdata_2021-01.csv.gz')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
len(df)
# Out:
# 1369765

# %%
#Let us explore issues with data types
df['VendorID']
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          2.0
#           ...
# 1369760    NaN
# 1369761    NaN
# 1369762    NaN
# 1369763    NaN
# 1369764    NaN
# Name: VendorID, Length: 1369765, dtype: float64

# %%
df['tpep_pickup_datetime']
# Out:
# 0          2021-01-01 00:30:10
# 1          2021-01-01 00:51:20
# 2          2021-01-01 00:43:30
# 3          2021-01-01 00:15:48
# 4          2021-01-01 00:31:49
#                   ...
# 1369760    2021-01-25 08:32:04
# 1369761    2021-01-25 08:34:00
# 1369762    2021-01-25 08:37:00
# 1369763    2021-01-25 08:28:00
# 1369764    2021-01-25 08:38:00
# Name: tpep_pickup_datetime, Length: 1369765, dtype: str

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    prefix + 'yellow_tripdata_2021-01.csv.gz',
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...           ...                  ...                   ...              ...
# 1369760      <NA>  2021-01-25 08:32:04   2021-01-25 08:49:32             <NA>
# 1369761      <NA>  2021-01-25 08:34:00   2021-01-25 09:04:00             <NA>
# 1369762      <NA>  2021-01-25 08:37:00   2021-01-25 08:53:00             <NA>
# 1369763      <NA>  2021-01-25 08:28:00   2021-01-25 08:50:00             <NA>
# 1369764      <NA>  2021-01-25 08:38:00   2021-01-25 08:50:00             <NA>
#
# ...

# %%
# !uv add sqlalchemy "psycopg[binary,pool]"
# Out:
# Resolved 120 packages in 0.64ms
# Audited 13 packages in 0.21ms

# %%
#Connect to the database
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
# !uv add psycopg2-binary
# Out:
# Resolved 120 packages in 0.65ms
# Audited 13 packages in 0.25ms

# %%
#Connect to the database
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# Split the DF into equal chunks and load them 1, by 1
url = prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/' + 'yellow_tripdata_2021-01.csv.gz'
df_iter = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=1000,
)

# %%
dfx = next(df_iter)

# %%
dfx
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1           1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2           1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3           1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4           2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..        ...                  ...                   ...              ...
# 995         1  2021-01-01 00:57:42   2021-01-01 01:08:18                1
# 996         2  2021-01-01 00:19:34   2021-01-01 00:31:34                1
# 997         2  2021-01-01 00:16:38   2021-01-01 00:24:23                3
# 998         2  2021-01-01 00:28:09   2021-01-01 00:40:08                1
# 999         2  2021-01-01 00:28:09   2021-01-01 00:40:08                1
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
for df in df_iter:
    print(len(df))
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# ...

# %%
#To view rogress of database insertion, we use tqdm lib
# !uv add tqdm
# Out:
# Resolved 120 packages in 0.66ms
# Audited 13 packages in 0.21ms

# %%
for df_chunk in df_iter:
    print(len(df_chunk))
    # df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

# %%
for i, chunk in enumerate(df_iter, start=1):
    print(f"Processing chunk {i}...")

    # chunk.to_sql(
    #     name="yellow_taxi_data",
    #     con=engine,
    #     if_exists="append",
    #     index=False,
    #     method="multi"
    # )

    # print(f"Inserted chunk {i}: {len(chunk)} rows")
